# %% [markdown]
# ## Impoting Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style="dargrid"

# %%
data=pd.read_csv("FuelConsumptionCo2.csv")
data.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %%
data.isnull().sum()
# Out:
# MODELYEAR                   0
# MAKE                        0
# MODEL                       0
# VEHICLECLASS                0
# ENGINESIZE                  0
# CYLINDERS                   0
# TRANSMISSION                0
# FUELTYPE                    0
# FUELCONSUMPTION_CITY        0
# FUELCONSUMPTION_HWY         0
# FUELCONSUMPTION_COMB        0
# FUELCONSUMPTION_COMB_MPG    0
# CO2EMISSIONS                0
# dtype: int64

# %%
data.describe().T
# Out:
#                            count         mean        std     min      25%  \
# MODELYEAR                 1067.0  2014.000000   0.000000  2014.0  2014.00
# ENGINESIZE                1067.0     3.346298   1.415895     1.0     2.00
# CYLINDERS                 1067.0     5.794752   1.797447     3.0     4.00
# FUELCONSUMPTION_CITY      1067.0    13.296532   4.101253     4.6    10.25
# FUELCONSUMPTION_HWY       1067.0     9.474602   2.794510     4.9     7.50
# FUELCONSUMPTION_COMB      1067.0    11.580881   3.485595     4.7     9.00
# FUELCONSUMPTION_COMB_MPG  1067.0    26.441425   7.468702    11.0    21.00
# CO2EMISSIONS              1067.0   256.228679  63.372304   108.0   207.00
#
#                              50%      75%     max
# MODELYEAR                 2014.0  2014.00  2014.0
# ENGINESIZE                   3.4     4.30     8.4
# CYLINDERS                    6.0     8.00    12.0
# FUELCONSUMPTION_CITY        12.6    15.55    30.2
# ...

# %%
fuel = data[["ENGINESIZE","CO2EMISSIONS"]]
fuel.head()
# Out:
#    ENGINESIZE  CO2EMISSIONS
# 0         2.0           196
# 1         2.4           221
# 2         1.5           136
# 3         3.5           255
# 4         3.5           244

# %%
sns.set_style="darkgrid"
sns.scatterplot(data=fuel,x="ENGINESIZE",y="CO2EMISSIONS",color="green")
# Out:
# <Axes: xlabel='ENGINESIZE', ylabel='CO2EMISSIONS'>

# %%
plt.scatter(fuel.ENGINESIZE,fuel.CO2EMISSIONS,color="green")

# %%
plt.scatter(fuel["ENGINESIZE"],fuel["CO2EMISSIONS"],color="green")

# %%
import plotly.express as px
fig=px.scatter(fuel,x="ENGINESIZE",y="CO2EMISSIONS")
fig.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Seaborn scatter plot
sns.scatterplot(data=fuel, x="ENGINESIZE", y="CO2EMISSIONS", color="green", ax=axes[0][0])
axes[0][0].set_title("Seaborn Scatter Plot")

# Matplotlib scatter plot 1
axes[0][1].scatter(fuel.ENGINESIZE, fuel.CO2EMISSIONS, color="green")
axes[0][1].set_title("Matplotlib Scatter Plot 1")

# Matplotlib scatter plot 2
axes[1][0].scatter(fuel["ENGINESIZE"], fuel["CO2EMISSIONS"], color="green")
axes[1][0].set_title("Matplotlib Scatter Plot 2")

# Leave space for Plotly mention
axes[1][1].axis('off')
axes[1][1].text(0.1, 0.5, "Plotly is Interactive\nRun Plot Separately", fontsize=12)

plt.tight_layout()
plt.show()

# Plotly interactive plot (run separately)
fig = px.scatter(fuel, x="ENGINESIZE", y="CO2EMISSIONS", color_discrete_sequence=['green'])
fig.update_layout(title="Plotly Scatter Plot")
fig.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(2, 2, figsize=(12, 8))  # 2x2 grid of subplots

# Seaborn scatter plot
sns.scatterplot(data=fuel, x="ENGINESIZE", y="CO2EMISSIONS", color="green", ax=axes[0][0])
axes[0][0].set_title("Seaborn Scatter Plot")

# Matplotlib scatter plot 1
axes[0][1].scatter(fuel.ENGINESIZE, fuel.CO2EMISSIONS, color="green")
axes[0][1].set_title("Matplotlib Scatter Plot 1")

# Matplotlib scatter plot 2
axes[1][0].scatter(fuel["ENGINESIZE"], fuel["CO2EMISSIONS"], color="green")
axes[1][0].set_title("Matplotlib Scatter Plot 2")

# Empty slot placeholder or plot
axes[1][1].axis('off')
axes[1][1].text(0.2, 0.5, "More plots or text here", fontsize=12)
#plotly 
fig = px.scatter(fuel, x="ENGINESIZE", y="CO2EMISSIONS", color_discrete_sequence=['green'])
fig.update_layout(title="Plotly Scatter Plot")
fig.show()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Splitting Dataset

# %%
fuel.head()
# Out:
#    ENGINESIZE  CO2EMISSIONS
# 0         2.0           196
# 1         2.4           221
# 2         1.5           136
# 3         3.5           255
# 4         3.5           244

# %%
from sklearn.model_selection import train_test_split
X=fuel.ENGINESIZE
y=fuel.CO2EMISSIONS
# Out:
# (1067,)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (853,)

# %%
X_test.shape
# Out:
# (214,)

# %%
y_train.shape
# Out:
# (853,)

# %% [markdown]
# ## Building and Training Linear Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)
print("RMSE:", mean_squared_error(y_test, y_pred, squared=False))
print("R²:", r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 5
#       2 from sklearn.metrics import mean_squared_error, r2_score
#       4 model = LinearRegression()
# ----> 5 model.fit(X_train, y_train)
#       7 # Predictions
#       8 y_pred = model.predict(X_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
# ...

# %%
train_X=np.array(X_train)

# %%
X_train = X_train.values.reshape(-1, 1) if X_train.ndim == 1 else X_train
X_test = X_test.values.reshape(-1, 1) if X_test.ndim == 1 else X_test

# %%
X_train.shape
# Out:
# (853, 1)

# %%
X_test.shape
# Out:
# (214, 1)

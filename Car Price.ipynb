# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style="darkgrid"

# %%
data = pd.read_csv("cars24data.csv")
data.head()
# Out:
#                             Model Name    Price  Manufacturing_year  \
# 0                2017 Maruti Swift VXI   561000                2017
# 1  2016 Maruti Baleno DELTA PETROL 1.2   498000                2016
# 2                2020 Maruti Swift VXI   577000                2020
# 3       2022 Maruti Ertiga VXI AT SHVS  1084000                2022
# 4                2019 Maruti Dzire VXI   603000                2019
#
#    Engine capacity Spare key Transmission  KM driven  Ownership Fuel type  \
# 0             1197        No       Manual      25847          2    Petrol
# 1             1197       Yes       Manual      55511          2    Petrol
# 2             1197        No       Manual      47110          1    Petrol
# 3             1462       Yes    Automatic      35378          1    Petrol
# 4             1197       Yes       Manual      91856          1    Petrol
#
#    Imperfections  Repainted Parts
# 0              6                2
# 1             12                1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Model Name          1445 non-null   object
#  1   Price               1445 non-null   int64
#  2   Manufacturing_year  1445 non-null   int64
#  3   Engine capacity     1445 non-null   int64
#  4   Spare key           1445 non-null   object
#  5   Transmission        1445 non-null   object
#  6   KM driven           1445 non-null   int64
#  7   Ownership           1445 non-null   int64
#  8   Fuel type           1445 non-null   object
#  9   Imperfections       1445 non-null   int64
#  10  Repainted Parts     1445 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 124.3+ KB

# %% [markdown]
# there are no null values

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.describe()
# Out:
#               Price  Manufacturing_year  Engine capacity      KM driven  \
# count  1.445000e+03         1445.000000      1445.000000    1445.000000
# mean   5.263543e+05         2017.817301      1142.104498   50588.903114
# std    1.963696e+05            2.986554       169.020818   27339.562631
# min    1.390000e+05         2010.000000       796.000000    1207.000000
# 25%    3.900000e+05         2016.000000       998.000000   28803.000000
# 50%    5.010000e+05         2018.000000      1197.000000   47849.000000
# 75%    6.310000e+05         2020.000000      1197.000000   70337.000000
# max    1.599000e+06         2023.000000      1462.000000  124716.000000
#
#          Ownership  Imperfections  Repainted Parts
# count  1445.000000    1445.000000      1445.000000
# mean      1.285121       9.597232         3.228374
# std       0.489877       8.398637         3.364578
# min       1.000000       0.000000         0.000000
# 25%       1.000000       3.000000         0.000000
# ...

# %%
data.describe(exclude=int)
# Out:
#                          Model Name Spare key Transmission Fuel type
# count                          1445      1445         1445      1445
# unique                          573         2            2         3
# top     2015 Maruti Wagon R 1.0 VXI       Yes       Manual    Petrol
# freq                             16       908         1073      1264

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Model Name          1445 non-null   object
#  1   Price               1445 non-null   int64
#  2   Manufacturing_year  1445 non-null   int64
#  3   Engine capacity     1445 non-null   int64
#  4   Spare key           1445 non-null   object
#  5   Transmission        1445 non-null   object
#  6   KM driven           1445 non-null   int64
#  7   Ownership           1445 non-null   int64
#  8   Fuel type           1445 non-null   object
#  9   Imperfections       1445 non-null   int64
#  10  Repainted Parts     1445 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 124.3+ KB

# %%
# Set figure size
fig, axes = plt.subplots(5, 2, figsize=(20, 35))
sns.histplot(data=data["Price"], ax=axes[0, 0], bins=20, kde=True,color="purple")
axes[0, 0].set_title("Price distribution")
axes[0, 0].set_ylabel("Count")
axes[0, 0].set_xlabel("Price")


sns.countplot(x=data["Manufacturing_year"], ax=axes[0, 1], palette="viridis", hue=data["Manufacturing_year"], legend=False)
axes[0, 1].set_title("Manufacturing_year distribution")
axes[0, 1].set_ylabel("Count")
axes[0, 1].set_xlabel("Year")


sns.histplot(x=data["Engine capacity"], ax=axes[1, 0], bins=20, kde=True,color="purple")
axes[1, 0].set_title("Engine capacity distribution")
axes[1, 0].set_ylabel("Count")
axes[1, 0].set_xlabel("Engine Capacity")


sns.countplot(x=data["Spare key"], ax=axes[1, 1], palette="viridis", hue=data["Spare key"], legend=False)
axes[1, 1].set_title("Spare key distribution")
axes[1, 1].set_ylabel("Count")
axes[1, 1].set_xlabel("Spare key")


sns.countplot(x=data["Transmission"], ax=axes[2, 0], palette="viridis", hue=data["Transmission"], legend=False)
axes[2, 0].set_title("Transmission distribution")
axes[2, 0].set_ylabel("Count")
axes[2, 0].set_xlabel("Transmission")



sns.histplot(x=data["KM driven"], ax=axes[2, 1], bins=20, kde=True, color="purple")
axes[2, 1].set_title("KM driven distribution")
axes[2, 1].set_ylabel("Count")
axes[2, 1].set_xlabel("KM distance")


sns.histplot(x=data["Ownership"], ax=axes[3, 0], bins=20, kde=True,color="purple")
axes[3, 0].set_title("Ownership distribution")
axes[3, 0].set_ylabel("Count")
axes[3, 0].set_xlabel("Ownership Count")


sns.countplot(x=data["Fuel type"], ax=axes[3, 1], palette="viridis", hue=data["Fuel type"], legend=False)
axes[3, 1].set_title("Fuel type distribution")
axes[3, 1].set_ylabel("Count")
axes[3, 1].set_xlabel("Fuel type")


sns.histplot(x=data["Imperfections"], ax=axes[4, 0], bins=20, kde=True,color="purple")
axes[4, 0].set_title("Imperfections distribution")
axes[4, 0].set_ylabel("Count")
axes[4, 0].set_xlabel("Imperfections")


sns.histplot(x=data["Repainted Parts"], ax=axes[4, 1], bins=20, kde=True, color="purple")
axes[4, 1].set_title("Repainted Parts distribution")
axes[4, 1].set_ylabel("Count")
axes[4, 1].set_xlabel("Repainted parts")
# Out:
# Text(0.5, 0, 'Repainted parts')

# %% [markdown]
# # Machine Learning

# %%
data.head()
# Out:
#                             Model Name    Price  Manufacturing_year  \
# 0                2017 Maruti Swift VXI   561000                2017
# 1  2016 Maruti Baleno DELTA PETROL 1.2   498000                2016
# 2                2020 Maruti Swift VXI   577000                2020
# 3       2022 Maruti Ertiga VXI AT SHVS  1084000                2022
# 4                2019 Maruti Dzire VXI   603000                2019
#
#    Engine capacity Spare key Transmission  KM driven  Ownership Fuel type  \
# 0             1197        No       Manual      25847          2    Petrol
# 1             1197       Yes       Manual      55511          2    Petrol
# 2             1197        No       Manual      47110          1    Petrol
# 3             1462       Yes    Automatic      35378          1    Petrol
# 4             1197       Yes       Manual      91856          1    Petrol
#
#    Imperfections  Repainted Parts
# 0              6                2
# 1             12                1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Model Name          1445 non-null   object
#  1   Price               1445 non-null   int64
#  2   Manufacturing_year  1445 non-null   int64
#  3   Engine capacity     1445 non-null   int64
#  4   Spare key           1445 non-null   object
#  5   Transmission        1445 non-null   object
#  6   KM driven           1445 non-null   int64
#  7   Ownership           1445 non-null   int64
#  8   Fuel type           1445 non-null   object
#  9   Imperfections       1445 non-null   int64
#  10  Repainted Parts     1445 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 124.3+ KB

# %%
data["Model Name"].nunique()
# Out:
# 573

# %% [markdown]
# # Standardisation

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
le = LabelEncoder()
scaler=StandardScaler()

# %%
for columns in data.select_dtypes("object").columns:
    data[columns]  = le.fit_transform(data[columns])

# %%
data.head()
# Out:
#    Model Name    Price  Manufacturing_year  Engine capacity  Spare key  \
# 0         222   561000                2017             1197          0
# 1         126   498000                2016             1197          1
# 2         410   577000                2020             1197          0
# 3         503  1084000                2022             1462          1
# 4         329   603000                2019             1197          1
#
#    Transmission  KM driven  Ownership  Fuel type  Imperfections  \
# 0             1      25847          2          2              6
# 1             1      55511          2          2             12
# 2             1      47110          1          2              4
# 3             0      35378          1          2              2
# 4             1      91856          1          2              3
#
#    Repainted Parts
# 0                2
# 1                1
# 2                2
# 3                3
# 4                2

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
dataa = scaler.fit_transform(data)

# %%
df = pd.DataFrame(dataa, columns=data.columns)

# %%
df.head()
# Out:
#    Model Name     Price  Manufacturing_year  Engine capacity  Spare key  \
# 0   -0.283678  0.176492           -0.273755         0.324898  -1.300337
# 1   -0.891945 -0.144443           -0.608705         0.324898   0.769032
# 2    0.907512  0.257999            0.731095         0.324898  -1.300337
# 3    1.496771  2.840759            1.400995         1.893295   0.769032
# 4    0.394286  0.390448            0.396145         0.324898   0.769032
#
#    Transmission  KM driven  Ownership  Fuel type  Imperfections  \
# 0      0.588805  -0.905299   1.459809   0.359712      -0.428460
# 1      0.588805   0.180098   1.459809   0.359712       0.286189
# 2      0.588805  -0.127292  -0.582228   0.359712      -0.666676
# 3     -1.698355  -0.556562  -0.582228   0.359712      -0.904892
# 4      0.588805   1.509950  -0.582228   0.359712      -0.785784
#
#    Repainted Parts
# 0        -0.365216
# 1        -0.662533
# 2        -0.365216
# 3        -0.067899
# 4        -0.365216

# %% [markdown]
# ## Predicting Price , using regression

# %% [markdown]
# #### Features Selection

# %%
df.head()
# Out:
#    Model Name     Price  Manufacturing_year  Engine capacity  Spare key  \
# 0   -0.283678  0.176492           -0.273755         0.324898  -1.300337
# 1   -0.891945 -0.144443           -0.608705         0.324898   0.769032
# 2    0.907512  0.257999            0.731095         0.324898  -1.300337
# 3    1.496771  2.840759            1.400995         1.893295   0.769032
# 4    0.394286  0.390448            0.396145         0.324898   0.769032
#
#    Transmission  KM driven  Ownership  Fuel type  Imperfections  \
# 0      0.588805  -0.905299   1.459809   0.359712      -0.428460
# 1      0.588805   0.180098   1.459809   0.359712       0.286189
# 2      0.588805  -0.127292  -0.582228   0.359712      -0.666676
# 3     -1.698355  -0.556562  -0.582228   0.359712      -0.904892
# 4      0.588805   1.509950  -0.582228   0.359712      -0.785784
#
#    Repainted Parts
# 0        -0.365216
# 1        -0.662533
# 2        -0.365216
# 3        -0.067899
# 4        -0.365216

# %%
X = df.drop(columns=["Price"])
y  =df["Price"]

# %%
X.shape
# Out:
# (1445, 10)

# %%
y.shape
# Out:
# (1445,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.svm import SVR, SVC
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
import time
models = {
    "Linear Regression":LinearRegression(),
    "Support Vector Machine":SVR(),
    "Random Forest":RandomForestRegressor(n_estimators=100, random_state=42),
    "DecisionTree":DecisionTreeRegressor(),
}

results_regression = []
for name,model in models.items():
    start_time = time.time()
    model.fit(X_train,y_train)
    pred = model.predict(X_test)
    end_time = time.time()
   
    elapsed_time = start_time-end_time
    r2 = r2_score(y_test,pred)*100
    results_regression.append({
        "Model":name,
        "R2_score":r2,
        "Time":elapsed_time
    })
    data_results_regression = pd.DataFrame(results_regression)
    print(data_results_regression)
# Out:
#                Model   R2_score      Time
# 0  Linear Regression  80.143239 -0.013992
#                     Model   R2_score      Time
# 0       Linear Regression  80.143239 -0.013992
# 1  Support Vector Machine  83.386018 -0.323800
#                     Model   R2_score      Time
# 0       Linear Regression  80.143239 -0.013992
# 1  Support Vector Machine  83.386018 -0.323800
# 2           Random Forest  89.260867 -0.839483
#                     Model   R2_score      Time
# 0       Linear Regression  80.143239 -0.013992
# 1  Support Vector Machine  83.386018 -0.323800
# 2           Random Forest  89.260867 -0.839483
# 3            DecisionTree  84.124873 -0.012992
